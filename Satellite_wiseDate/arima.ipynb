# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm

# %%
df = pd.read_csv('1.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0               int64
# PRN                      int64
# Epoch_Time_of_Clock      int64
# SV_Clock_Bias          float64
# SV_Clock_Drift         float64
# SV_Clock_Drift_Rate      int64
# IODE                     int64
# Crs                    float64
# Del_n                  float64
# M0                     float64
# Cuc                    float64
# e                      float64
# Cus                    float64
# sqrt_A                 float64
# Toe                      int64
# Cic                    float64
# OMEGA                  float64
# Cis                    float64
# i0                     float64
# Crc                    float64
# omega                  float64
# OMEGA_dot              float64
# I_dot                  float64
# Codes                    int64
# GPS_week                 int64
# L2_P_Data_flag           int64
# SV_accuracy              int64
# SV_health                int64
# Tgd                    float64
# IODC                     int64
# ...

# %%
df[['Del_n']].plot()
plt.show()
df[['M0']].plot()
plt.show()
df[['Del_n','M0']].plot()
plt.show()

# %%
print(sm.tsa.stattools.adfuller(df['Del_n']))
print(sm.tsa.stattools.adfuller(df['M0']))
# Out:
# (-5.127798906034267, 1.2322499077929962e-05, 14, 162, {'1%': -3.471374345647024, '5%': -2.8795521079291966, '10%': -2.5763733302850174}, -7361.631565730935)
# (-1.9270083800420625, 0.31946410969282774, 12, 164, {'1%': -3.47086589632514, '5%': -2.879330279087651, '10%': -2.57625492712671}, 398.1031257915715)
