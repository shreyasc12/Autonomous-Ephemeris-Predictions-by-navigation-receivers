# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  PRN  Epoch_Time_of_Clock  SV_Clock_Bias  \
# 0           0            80    1  2017-11-01 14:00:00      -0.000008
# 1           1            88    1  2017-11-01 16:00:00      -0.000008
# 2           2           101    1  2017-11-01 18:00:00      -0.000008
# 3           3           109    1  2017-11-01 20:00:00      -0.000008
# 4           4           124    1  2017-11-01 22:00:00      -0.000008
#
#    SV_Clock_Drift  SV_Clock_Drift_Rate  IODE       Crs         Del_n  \
# 0   -2.387424e-12                    0    30  20.71875  4.874846e-09
# 1   -2.387424e-12                    0    31  16.81250  4.916991e-09
# 2   -2.387424e-12                    0    32  13.84375  4.874846e-09
# 3   -2.387424e-12                    0    33  12.28125  4.875203e-09
# 4   -2.387424e-12                    0    34  23.03125  4.753055e-09
#
#        ...              I_dot  Codes  GPS_week  L2_P_Data_flag  SV_accuracy  \
# ...

# %%
#sqr_A = np.square(df.iloc[:,14:15])
#np.power(sqr_A, 2)


#for i in range(0,177):
GM = 3.986005 * 10**14
e = 7.292115*10**(-5)
crs = []
e = []
io = []
Omega = []
omega = []
M0 = []
Del_n = []
Omega_dot = []
i_dot = []
cus = []
cuc = []
crc = []
cis = []
cic = []

# %%
sqr_A
# Out:
#            sqrt_A
# 0    2.656032e+07
# 1    2.656031e+07
# 2    2.656031e+07
# 3    2.656032e+07
# 4    2.656035e+07
# 5    2.656034e+07
# 6    2.656034e+07
# 7    2.656031e+07
# 8    2.656030e+07
# 9    2.656030e+07
# 10   2.656031e+07
# 11   2.656034e+07
# 12   2.656035e+07
# 13   2.656032e+07
# 14   2.656031e+07
# 15   2.656031e+07
# 16   2.656032e+07
# 17   2.656034e+07
# 18   2.656037e+07
# 19   2.656035e+07
# 20   2.656034e+07
# 21   2.656033e+07
# 22   2.656035e+07
# 23   2.656036e+07
# 24   2.656040e+07
# 25   2.656038e+07
# 26   2.656037e+07
# 27   2.656038e+07
# 28   2.656038e+07
# 29   2.656039e+07
# ..            ...
# 147  2.656041e+07
# 148  2.656040e+07
# 149  2.656042e+07
# 150  2.656040e+07
# 151  2.656039e+07
# 152  2.656039e+07
# 153  2.656038e+07
# 154  2.656039e+07
# 155  2.656039e+07
# 156  2.656041e+07
# 157  2.656038e+07
# 158  2.656037e+07
# 159  2.656036e+07
# 160  2.656035e+07
# 161  2.656036e+07
# 162  2.656036e+07
# 163  2.656039e+07
# 164  2.656037e+07
# ...
