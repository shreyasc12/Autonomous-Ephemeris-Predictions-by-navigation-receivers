# %% [markdown]
# ### Multi step model (simple encoder-decoder)
#
# In this notebook, we demonstrate how to:
# - prepare time series data for training a RNN forecasting model
# - get data in the required shape for the keras API
# - implement a RNN model in keras to predict the next 3 steps ahead (time *t+1* to *t+3*) in the time series. This model uses a simple encoder decoder approach in which the final hidden state of the encoder is replicated across each time step of the decoder.
# - enable early stopping to reduce the likelihood of model overfitting
# - evaluate the model on a test dataset
#
# The data in this example is taken from the GEFCom2014 forecasting competition<sup>1</sup>. It consists of 3 years of hourly electricity load and temperature values between 2012 and 2014. The task is to forecast future values of electricity load.
#
# <sup>1</sup>Tao Hong, Pierre Pinson, Shu Fan, Hamidreza Zareipour, Alberto Troccoli and Rob J. Hyndman, "Probabilistic energy forecasting: Global Energy Forecasting Competition 2014 and beyond", International Journal of Forecasting, vol.32, no.3, pp 896-913, July-September, 2016.

# %%
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
from collections import UserDict
from IPython.display import Image
# %matplotlib inline

from common.utils import load_data, mape, TimeSeriesTensor, create_evaluation_df

pd.options.display.float_format = '{:,.20f}'.format
np.set_printoptions(precision=20)
warnings.filterwarnings("ignore")

# %%
sat_var = 2
var_name = 'i0'

# %%
Paras = {
     'M0':['M0'],
    'e':['OMEGA','i0','omega','I_dot','Cus','Crs','e' , 'M0'],
    'sqrt_A':['Cuc','Crc','Del_n','Crs','sqrt_A','OMEGA_dot','Cus'],
    'OMEGA':['OMEGA','e','i0','omega'],
    'i0':['e','i0','omega','OMEGA' ,'I_dot'],
    'omega':['omega','e','OMEGA','i0'],
    'I_dot':['I_dot','e','Crs','Cuc'],
    'Cic':['M0','Cic'],
    'Cis':['Cis'],
    'OMEGA_dot':['OMEGA_dot','sqrt_A','Crc','Del_n','Cus' , 'omega' ],
    'Cuc':['Cuc','e','sqrt_A','I_dot','Crs'],
    'Cus':['Cus','sqrt_A','OMEGA_dot','Crc','Del_n','Cus'],
    'Crc':['Crc','sqrt_A','OMEGA_dot','Cus','Del_n'],
    'Crs':['Crs'],
    'Del_n':['Crc','sqrt_A','OMEGA_dot','Cus','Del_n'],
    'Codes' : ['Codes']    
}

# %%
df = pd.read_csv("Cleaned1.csv" , parse_dates = True)
a = pd.to_datetime(df['Epoch_Time_of_Clock'])
print(type(a[0]))
df = df.drop(['Unnamed: 0', 'Unnamed: 0.1' ,'sqrt_A' ,'e' ,'PRN','SV_Clock_Bias', 'SV_Clock_Drift', 'SV_Clock_Drift_Rate', 'IODE', 'Crs',
       'Del_n', 'M0', 'Cuc','Cus','Toe', 'Cic', 'OMEGA',
       'Cis', 'Crc', 'omega', 'OMEGA_dot', 'I_dot', 'Codes', 'GPS_week',
       'L2_P_Data_flag', 'SV_accuracy', 'SV_health', 'Tgd', 'IODC', 'T_Tx',
       'Fit_Interval' ,'Epoch_Time_of_Clock' ],axis =1 )
df.head()
#df = df.set_index(['Epoch_Time_of_Clock'])
df = df.set_index(a)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4b6aa970a8c9> in <module>()
# ----> 1 df = pd.read_csv("Cleaned1.csv" , parse_dates = True)
#       2 a = pd.to_datetime(df['Epoch_Time_of_Clock'])
#       3 print(type(a[0]))
#       4 df = df.drop(['Unnamed: 0', 'Unnamed: 0.1' ,'sqrt_A' ,'e' ,'PRN','SV_Clock_Bias', 'SV_Clock_Drift', 'SV_Clock_Drift_Rate', 'IODE', 'Crs',
#       5        'Del_n', 'M0', 'Cuc','Cus','Toe', 'Cic', 'OMEGA',
#
# NameError: name 'pd' is not defined

# %%
test = df.iloc[265:408,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3b5f5b158241> in <module>()
# ----> 1 test = df.iloc[265:408,:]
#
# NameError: name 'df' is not defined

# %%
df.head(7)
# Out:
#                                         i0
# Epoch_Time_of_Clock
# 2017-11-02 12:00:00 0.96873138917400003489
# 2017-11-02 14:00:00 0.96873510791099992634
# 2017-11-02 16:00:00 0.96873808348699996795
# 2017-11-02 18:00:00 0.96874178466900007223
# 2017-11-02 20:00:00 0.96874462858199994475
# 2017-11-02 22:00:00 0.96874790990700010429
# 2017-11-03 12:00:00 0.96876999411899999970

# %% [markdown]
# # Enter number of entries per day

# %%
'''entry = 6
print(df.shape[0])
no_of_entries = df.shape[0]//entry
valid = (no_of_entries * 70)//100
test = (no_of_entries * 85)//100
indexes = df.index
#print(valid , test , indexes)
valid_start_dt = indexes[int(valid)*int(entry)] 
test_start_dt = indexes [int(test)*int(entry)] 
test_start_dt = str(test_start_dt)
valid_start_dt = str(valid_start_dt)
print(test_start_dt,valid_start_dt)
print(type(test_start_dt))'''
valid_start_dt = '2017-11-07 00:00:00'
test_start_dt = '2017-11-10 00:00:00'

# %% [markdown]
# Load data into Pandas dataframe

# %% [markdown]
# # enter lag and no. of outputs

# %%
"""total = len(df)
t = total*70/100
t = round(t)
indexes = df.index
valid_start_dt = str(indexes[t])
t = total*85/100
t = round(t)
test_start_dt = str(indexes[t])
print(valid_start_dt , test_start_dt)
"""
T = 24
HORIZON = 24

# %% [markdown]
# Create training set containing only the model features

# %%
train = df.copy()[df.index < valid_start_dt][[var_name]]
train.head()
# Out:
#                                         i0
# Epoch_Time_of_Clock
# 2017-11-02 12:00:00 0.96873138917400003489
# 2017-11-02 14:00:00 0.96873510791099992634
# 2017-11-02 16:00:00 0.96873808348699996795
# 2017-11-02 18:00:00 0.96874178466900007223
# 2017-11-02 20:00:00 0.96874462858199994475

# %%
train.tail(6)
# Out:
#                                         i0
# Epoch_Time_of_Clock
# 2017-11-20 12:00:00 0.96928713858600001885
# 2017-11-20 14:00:00 0.96929108846399991695
# 2017-11-20 16:00:00 0.96929521535600005055
# 2017-11-20 18:00:00 0.96929829479899998201
# 2017-11-20 20:00:00 0.96930164341800006955
# 2017-11-20 22:00:00 0.96930452683000001279

# %% [markdown]
# Scale data to be in range (0, 1). This transformation should be calibrated on the training set only. This is to prevent information from the validation or test sets leaking into the training data.

# %% [markdown]
# # Enter variable to be predicted

# %%
from sklearn.preprocessing import StandardScaler




y_scalar = StandardScaler()
y_scalar.fit(train[[var_name]])


X_scaler = StandardScaler()
train[[var_name]] = X_scaler.fit_transform(train)

# %% [markdown]
# Use the TimeSeriesTensor convenience class to:
# 1. Shift the values of the time series to create a Pandas dataframe containing all the data for a single training example
# 2. Discard any samples with missing values
# 3. Transform this Pandas dataframe into a numpy array of shape (samples, time steps, features) for input into Keras
#
# The class takes the following parameters:
#
# - **dataset**: original time series
# - **H**: the forecast horizon
# - **tensor_structure**: a dictionary discribing the tensor structure in the form { 'tensor_name' : (range(max_backward_shift, max_forward_shift), [feature, feature, ...] ) }
# - **freq**: time series frequency
# - **drop_incomplete**: (Boolean) whether to drop incomplete samples

# %%
tensor_structure = {'X':(range(-T+1, 1), [var_name])}
train_inputs = TimeSeriesTensor(train, var_name, HORIZON, {'X':(range(-T+1, 1), [var_name])} ,freq = None)

# %%
train_inputs.dataframe
# Out:
# tensor                               target                          \
# feature                                   y
# time step                               t+1                     t+2
# Epoch_Time_of_Clock
# 2017-11-02 22:00:00
# 2017-11-18 12:00:00  0.99799713490751584821  1.19651805407745759346
# 2017-11-18 14:00:00  1.19651805407745759346  1.23075966483360810244
# 2017-11-18 16:00:00  1.23075966483360810244  1.26524873052799446960
# 2017-11-18 18:00:00  1.26524873052799446960  1.29479900159029193141
# 2017-11-18 20:00:00  1.29479900159029193141  1.32501946605232201470
# 2017-11-18 22:00:00  1.32501946605232201470  1.35341494504705206481
# 2017-11-19 12:00:00  1.35341494504705206481  1.54544016852877508228
# 2017-11-19 14:00:00  1.54544016852877508228  1.57776399997676719522
# 2017-11-19 16:00:00  1.57776399997676719522  1.61075802482370944446
# 2017-11-19 18:00:00  1.61075802482370944446  1.63723572451184629095
# 2017-11-19 20:00:00  1.63723572451184629095  1.66505381099710092485
# 2017-11-19 22:00:00  1.66505381099710092485  1.69042828171573433771
#
# [103 rows x 12 columns]

# %%
train_inputs['target'].shape
# Out:
# (103, 6)

# %% [markdown]
# Construct validation set (keeping T hours from the training set in order to construct initial features)

# %%
look_back_dt = dt.datetime.strptime(valid_start_dt, '%Y-%m-%d %H:%M:%S') - dt.timedelta(hours=T-1)
valid = df.copy()[(df.index >=look_back_dt) & (df.index < test_start_dt)][['i0']]
valid[[var_name]] = X_scaler.transform(valid)
valid_inputs = TimeSeriesTensor(valid, var_name, HORIZON, tensor_structure,freq = None)
valid_inputs.dataframe.head()
# Out:
# tensor                              target                         \
# feature                                  y
# time step                              t+1                    t+2
# Epoch_Time_of_Clock
# 2017-11-21 22:00:00 2.29645632516392872446 2.31100462465059042216
# 2017-11-22 12:00:00 2.31100462465059042216 2.32807902958471046873
# 2017-11-22 14:00:00 2.32807902958471046873 2.33818345136750238566
# 2017-11-22 16:00:00 2.33818345136750238566 2.35079335617734752617
# 2017-11-22 18:00:00 2.35079335617734752617 2.35975329710199188682
#
# tensor                                                             \
# feature
# time step                              t+3                    t+4
# Epoch_Time_of_Clock
# 2017-11-21 22:00:00 2.32807902958471046873 2.33818345136750238566
# 2017-11-22 12:00:00 2.33818345136750238566 2.35079335617734752617
# 2017-11-22 14:00:00 2.35079335617734752617 2.35975329710199188682
# 2017-11-22 16:00:00 2.35975329710199188682 2.40531598191953444044
# 2017-11-22 18:00:00 2.40531598191953444044 2.41312113077582868215
#
# tensor                                                             \
# feature
# time step                              t+5                    t+6
# Epoch_Time_of_Clock
# 2017-11-21 22:00:00 2.35079335617734752617 2.35975329710199188682
# 2017-11-22 12:00:00 2.35975329710199188682 2.40531598191953444044
# 2017-11-22 14:00:00 2.40531598191953444044 2.41312113077582868215
# 2017-11-22 16:00:00 2.41312113077582868215 2.42405040000867932903
# 2017-11-22 18:00:00 2.42405040000867932903 2.42887577838107038275
#
# tensor                                   X                         \
# feature                                 i0
# time step                              t-5                    t-4
# Epoch_Time_of_Clock
# 2017-11-21 22:00:00 2.11345290986650002907 2.13504337097355989528
# 2017-11-22 12:00:00 2.13504337097355989528 2.15852068480444048149
# 2017-11-22 14:00:00 2.15852068480444048149 2.17450216492829540016
# 2017-11-22 16:00:00 2.17450216492829540016 2.19277259972061155935
# 2017-11-22 18:00:00 2.19277259972061155935 2.20758898361531352705
#
# tensor                                                             \
# feature
# time step                              t-3                    t-2
# Epoch_Time_of_Clock
# 2017-11-21 22:00:00 2.15852068480444048149 2.17450216492829540016
# 2017-11-22 12:00:00 2.17450216492829540016 2.19277259972061155935
# 2017-11-22 14:00:00 2.19277259972061155935 2.20758898361531352705
# 2017-11-22 16:00:00 2.20758898361531352705 2.29645632516392872446
# 2017-11-22 18:00:00 2.29645632516392872446 2.31100462465059042216
#
# tensor
# feature
# time step                              t-1                      t
# Epoch_Time_of_Clock
# 2017-11-21 22:00:00 2.19277259972061155935 2.20758898361531352705
# 2017-11-22 12:00:00 2.20758898361531352705 2.29645632516392872446
# 2017-11-22 14:00:00 2.29645632516392872446 2.31100462465059042216
# 2017-11-22 16:00:00 2.31100462465059042216 2.32807902958471046873
# 2017-11-22 18:00:00 2.32807902958471046873 2.33818345136750238566

# %% [markdown]
# ## Implement the RNN

# %% [markdown]
# We will implement a RNN forecasting model with the following structure:

# %%
#Image('./images/simple_encoder_decoder.png')

# %%
from keras.models import Model, Sequential
from keras.layers import LSTM, Dense, RepeatVector, TimeDistributed, Flatten
from keras.callbacks import EarlyStopping ,ModelCheckpoint

# %%
LATENT_DIM = 64
BATCH_SIZE = 8
EPOCHS = 10

# %%
model = Sequential()
model.add(LSTM(LATENT_DIM, input_shape=(T,1 )))
model.add(RepeatVector(HORIZON))
model.add(LSTM(LATENT_DIM, return_sequences=True))
model.add(TimeDistributed(Dense(1)))
model.add(Flatten())

# %%
model.compile(optimizer='RMSprop', loss='mse')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 64)                16896
# _________________________________________________________________
# repeat_vector_4 (RepeatVecto (None, 6, 64)             0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 6, 64)             33024
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 6, 1)              65
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 6)                 0
# =================================================================
# Total params: 49,985
# Trainable params: 49,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=500)

# %%
best_val = ModelCheckpoint(str(sat_var) +'_' +  var_name + '_{epoch:02d}.h5', save_best_only=True, mode='min', period=1)

# %%
history = model.fit(train_inputs['X'],
          train_inputs['target'],
          batch_size=BATCH_SIZE,
          epochs=EPOCHS,
          validation_data=(valid_inputs['X'], valid_inputs['target']),
          callbacks=[earlystop ,best_val],
          verbose=1 , shuffle = False)
# Out:
# Train on 103 samples, validate on 13 samples
# Epoch 1/10
# 103/103 [==============================] - 2s 17ms/step - loss: 0.5525 - val_loss: 2.1879
# Epoch 2/10
# 103/103 [==============================] - 0s 1ms/step - loss: 0.1861 - val_loss: 0.7920
# Epoch 3/10
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1195 - val_loss: 0.6202
# Epoch 4/10
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1028 - val_loss: 0.4573
# Epoch 5/10
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0887 - val_loss: 0.3901
# Epoch 6/10
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0786 - val_loss: 0.4121
# Epoch 7/10
# 103/103 [==============================] - 0s 1ms/step - loss: 0.0712 - val_loss: 0.4050
# Epoch 8/10
# 103/103 [==============================] - 0s 1ms/step - loss: 0.0656 - val_loss: 0.3844
# Epoch 9/10
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0612 - val_loss: 0.3592
# Epoch 10/10
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0574 - val_loss: 0.3312

# %%
best_epoch = np.argmin(np.array(history.history['val_loss']))+1
model.load_weights(str(sat_var) +'_' +  var_name + '_{:02d}.h5',.format(best_epoch))
# Out:
#   File "<ipython-input-139-b59392cdf9de>", line 2
#     model.load_weights(str(sat_var) +'_' +  var_name + '_{:02d}.h5',.format(best_epoch))
#                                                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Evaluate the model

# %%
look_back_dt = dt.datetime.strptime(test_start_dt, '%Y-%m-%d %H:%M:%S') - dt.timedelta(hours=T-1)
test = df.copy()[test_start_dt:][[var_name]]
test[[var_name]] = X_scaler.transform(test)
test_inputs = TimeSeriesTensor(test, var_name, HORIZON, tensor_structure,freq =None)
test_inputs.dataframe.head()

# %%
test_inputs.dataframe.head(50)

# %%
test_inputs.dataframe.shape

# %%
predictions = model.predict(test_inputs['X'])

# %%
predictions
# Out:
# array([[1.7569126, 2.6331668, 2.9987226, 3.1351244, 3.1777024, 3.1834924],
#        [1.7557682, 2.6314144, 2.9966822, 3.1329343, 3.1754243, 3.1811604],
#        [1.7545671, 2.6296003, 2.9945874, 3.1306894, 3.1730862, 3.1787632],
#        [1.7531952, 2.627573 , 2.9922833, 3.1282396, 3.1705427, 3.176156 ],
#        [1.7517545, 2.6254563, 2.9898872, 3.1257002, 3.1679099, 3.1734586],
#        [1.7502238, 2.6232276, 2.9873817, 3.1230533, 3.1651688, 3.1706512],
#        [1.7487284, 2.6210566, 2.984945 , 3.1204834, 3.1625102, 3.1679292],
#        [1.7483817, 2.6205192, 2.984315 , 3.119804 , 3.1618032, 3.167205 ],
#        [1.7481971, 2.6202347, 2.9839811, 3.119443 , 3.161425 , 3.1668167],
#        [1.7480913, 2.620096 , 2.9838376, 3.1192966, 3.1612744, 3.1666615],
#        [1.7481489, 2.6201985, 2.9839687, 3.119444 , 3.1614306, 3.166822 ],
#        [1.7483606, 2.6205385, 2.984377 , 3.1198895, 3.1618972, 3.1673005],
#        [1.7488233, 2.6212454, 2.9851995, 3.120774 , 3.1628191, 3.1682458],
#        [1.7514004, 2.625115 , 2.989646 , 3.12552  , 3.1677485, 3.1732936],
#        [1.7543765, 2.6295583, 2.9947329, 3.1309452, 3.1733851, 3.1790695],
#        [1.7577409, 2.634575 , 3.0004702, 3.1370592, 3.1797357, 3.185576 ],
#        [1.7615601, 2.6402347, 3.0069156, 3.1439137, 3.1868505, 3.1928656],
#        [1.7658069, 2.6465092, 3.0140455, 3.151486 , 3.1947062, 3.200913 ],
#        [1.7705041, 2.6534243, 3.0218832, 3.1597996, 3.2033257, 3.2097423]],
#       dtype=float32)

# %%
eval_df = create_evaluation_df(predictions, test_inputs, HORIZON, y_scalar)
print(eval_df.head())
print(eval_df.tail())
print(eval_df.shape)
# Out:
#             timestamp    h             prediction                 actual
# 0 2017-11-25 22:00:00  t+1 0.96927267783222970099 0.96936711485400006705
# 1 2017-11-26 12:00:00  t+1 0.96927251545839965274 0.96936699928399994164
# 2 2017-11-26 14:00:00  t+1 0.96927234505044790325 0.96936746156599995494
# 3 2017-11-26 16:00:00  t+1 0.96927215038790526247 0.96936730503299994854
# 4 2017-11-26 18:00:00  t+1 0.96927194598293286987 0.96936748204699996201
#               timestamp    h             prediction                 actual
# 109 2017-11-28 14:00:00  t+6 0.96947445973998869206 0.96939360098600002580
# 110 2017-11-28 16:00:00  t+6 0.96947538290286783269 0.96939672138999999351
# 111 2017-11-28 18:00:00  t+6 0.96947641719033683660 0.96939893478499994384
# 112 2017-11-28 20:00:00  t+6 0.96947755898281240405 0.96940160022200005940
# 113 2017-11-28 22:00:00  t+6 0.96947881173073846561 0.96940404768400001423
# (114, 4)

# %%
eval_df['APE'] = (eval_df['prediction'] - eval_df['actual']).abs() / eval_df['actual']
eval_df.groupby('h')['APE'].mean()
# Out:
# h
# t+1   0.00010223037893880495
# t+2   0.00002437381961913638
# t+3   0.00007617722607176709
# t+4   0.00009438757207413820
# t+5   0.00009872784177720284
# t+6   0.00009756955015960501
# Name: APE, dtype: float64

# %%
mape(eval_df['prediction'], eval_df['actual'])
from sklearn.metrics import mean_absolute_error
a = mean_absolute_error(eval_df['prediction'], eval_df['actual'])
a
# Out:
# 7.972563640892876e-05

# %% [markdown]
# Plot actuals vs predictions at each horizon for first week of the test period. As is to be expected, predictions for one step ahead (*t+1*) are more accurate than those for 2 or 3 steps ahead

# %%
plot_df = eval_df[(eval_df.h=='t+1')][['timestamp', 'actual']]
for t in range(1, HORIZON+1):
    plot_df['t+'+str(t)] = eval_df[ (eval_df.h=='t+'+str(t))]['prediction'].values

fig = plt.figure(figsize=(15, 8))
ax = plt.plot(plot_df['timestamp'], plot_df['actual'], color='red', linewidth=4.0)
ax = fig.add_subplot(111)
ax.plot(plot_df['timestamp'], plot_df['t+1'], color='blue', linewidth=4.0, alpha=0.75)
ax.plot(plot_df['timestamp'], plot_df['t+2'], color='blue', linewidth=3.0, alpha=0.5)
ax.plot(plot_df['timestamp'], plot_df['t+3'], color='blue', linewidth=2.0, alpha=0.25)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
ax.legend(loc='best')
plt.show()

# %% [markdown]
# # take input here

# %%
a = df.iloc[156:162  , :]
a
# Out:
#                                         i0
# Epoch_Time_of_Clock
# 2017-11-28 12:00:00 0.96937252618799996107
# 2017-11-28 14:00:00 0.96937375503900002904
# 2017-11-28 16:00:00 0.96937560416800006013
# 2017-11-28 18:00:00 0.96937668087500006298
# 2017-11-28 20:00:00 0.96937815257100001798
# 2017-11-28 22:00:00 0.96937943993899999828

# %%
new_df = pd.DataFrame()

# %%
columns = [var_name]

# %%
for key , value in enumerate(columns):
    new_df[value] = a[value]

# %%
new_df = new_df.dropna( how = 'any')

# %%
new_df
# Out:
#                                         i0
# Epoch_Time_of_Clock
# 2017-11-28 12:00:00 0.96937252618799996107
# 2017-11-28 14:00:00 0.96937375503900002904
# 2017-11-28 16:00:00 0.96937560416800006013
# 2017-11-28 18:00:00 0.96937668087500006298
# 2017-11-28 20:00:00 0.96937815257100001798
# 2017-11-28 22:00:00 0.96937943993899999828

# %%
# creating index for output
import datetime
date = new_df.index.date[0]
date + datetime.timedelta(1)
# Out:
# datetime.date(2017, 11, 29)

# %%
import datetime
date = new_df.index + datetime.timedelta(days =1)

# %%
date
# Out:
# DatetimeIndex(['2017-11-29 12:00:00', '2017-11-29 14:00:00',
#                '2017-11-29 16:00:00', '2017-11-29 18:00:00',
#                '2017-11-29 20:00:00', '2017-11-29 22:00:00'],
#               dtype='datetime64[ns]', name='Epoch_Time_of_Clock', freq='2H')

# %%
new_df.index= date

# %%
new_df.columns
# Out:
# Index(['i0'], dtype='object')

# %%
print(new_df)
print(new_df.columns)
# Out:
#                                         i0
# Epoch_Time_of_Clock
# 2017-11-29 12:00:00 0.96937252618799996107
# 2017-11-29 14:00:00 0.96937375503900002904
# 2017-11-29 16:00:00 0.96937560416800006013
# 2017-11-29 18:00:00 0.96937668087500006298
# 2017-11-29 20:00:00 0.96937815257100001798
# 2017-11-29 22:00:00 0.96937943993899999828
# Index(['i0'], dtype='object')

# %%
freq = None
idx_tuples = []
drop_incomplete  = True
new_df[[var_name]] = X_scaler.transform(new_df)
new_new_df = new_df.copy()
tensor_structure={'X':(range(-T+1, 1), [var_name])}
for name, structure in tensor_structure.items():
        rng = structure[0]
        dataset_cols = structure[1]
        for col in dataset_cols:
        # do not shift non-sequential 'static' features
            if rng is None:
                new_df['context_'+col] = new_df[col]
                idx_tuples.append((name, col, 'static'))
            else:
                for t in rng:
                    sign = '+' if t > 0 else ''
                    shift = str(t) if t != 0 else ''
                    period = 't'+sign+shift
                    shifted_col = name+'_'+col+'_'+ period
                    new_new_df[shifted_col] = new_new_df[col].shift(t*-1, freq=freq)
                    idx_tuples.append((name, col, period))
        new_new_df = new_new_df.drop(new_df.columns, axis=1)
        idx = pd.MultiIndex.from_tuples(idx_tuples, names=['tensor', 'feature', 'time step'])
        print(new_df.head())
        new_new_df.columns = idx
        if drop_incomplete:
            new_new_df = new_new_df.dropna(how='any')
            
inputs = {}           
for name, structure in tensor_structure.items():
    rng = structure[0]
    cols = structure[1]
    tensor = new_new_df[name][cols].as_matrix()
    if rng is None:
        tensor = tensor.reshape(tensor.shape[0], len(cols))
    else:
        tensor = tensor.reshape(tensor.shape[0], len(cols), len(rng))
        tensor = np.transpose(tensor, axes=[0, 2, 1])
    inputs[name] = tensor
# Out:
#                                         i0
# Epoch_Time_of_Clock
# 2017-11-29 12:00:00 2.46064283269059291825
# 2017-11-29 14:00:00 2.46930376262755357786
# 2017-11-29 16:00:00 2.48233640589576509683
# 2017-11-29 18:00:00 2.48992502639503143769
# 2017-11-29 20:00:00 2.50029752553724682329

# %%
print(new_new_df)
print(inputs['X'])
# Out:
# tensor                                   X                         \
# feature                                 i0
# time step                              t-5                    t-4
# Epoch_Time_of_Clock
# 2017-11-29 22:00:00 2.46064283269059291825 2.46930376262755357786
#
# tensor                                                             \
# feature
# time step                              t-3                    t-2
# Epoch_Time_of_Clock
# 2017-11-29 22:00:00 2.48233640589576509683 2.48992502639503143769
#
# tensor
# feature
# time step                              t-1                      t
# Epoch_Time_of_Clock
# 2017-11-29 22:00:00 2.50029752553724682329 2.50937088272237174280
# [[[2.460642832690593 ]
#   [2.4693037626275536]
#   [2.482336405895765 ]
#   [2.4899250263950314]
#   [2.500297525537247 ]
#   [2.5093708827223717]]]

# %%
predictions = model.predict(inputs['X'])

# %%
predictions
# Out:
# array([[1.2471302, 2.0418622, 2.5105414, 2.7703724, 2.9061916, 2.9721932]],
#       dtype=float32)

# %%
print(predictions.shape)
# Out:
# (1, 6)

# %%
results = predictions[-1, :]

# %%
results
# Out:
# array([1.2471302, 2.0418622, 2.5105414, 2.7703724, 2.9061916, 2.9721932],
#       dtype=float32)

# %%
res_df = pd.DataFrame(results , columns = [var_name])
res_df
# Out:
#                       i0
# 0 1.24713015556335449219
# 1 2.04186224937438964844
# 2 2.51054143905639648438
# 3 2.77037239074707031250
# 4 2.90619158744812011719
# 5 2.97219324111938476562

# %%
res_df.index = date
res_df
# Out:
#                                         i0
# Epoch_Time_of_Clock
# 2017-11-29 12:00:00 1.24713015556335449219
# 2017-11-29 14:00:00 2.04186224937438964844
# 2017-11-29 16:00:00 2.51054143905639648438
# 2017-11-29 18:00:00 2.77037239074707031250
# 2017-11-29 20:00:00 2.90619158744812011719
# 2017-11-29 22:00:00 2.97219324111938476562

# %%
res_df[var_name] = y_scalar.inverse_transform(res_df[[var_name]])

# %% [markdown]
# # final generated output

# %%
# final generated ouput
res_df
# Out:
#                                         i0
# Epoch_Time_of_Clock
# 2017-11-29 12:00:00 0.96920037269592285156
# 2017-11-29 14:00:00 0.96931308507919311523
# 2017-11-29 16:00:00 0.96937960386276245117
# 2017-11-29 18:00:00 0.96941649913787841797
# 2017-11-29 20:00:00 0.96943575143814086914
# 2017-11-29 22:00:00 0.96944510936737060547

# %%
res_df.to_csv('SA1i0.csv')
