# %% [markdown]
# ### Multi step model (simple encoder-decoder)
#
# In this notebook, we demonstrate how to:
# - prepare time series data for training a RNN forecasting model
# - get data in the required shape for the keras API
# - implement a RNN model in keras to predict the next 3 steps ahead (time *t+1* to *t+3*) in the time series. This model uses a simple encoder decoder approach in which the final hidden state of the encoder is replicated across each time step of the decoder.
# - enable early stopping to reduce the likelihood of model overfitting
# - evaluate the model on a test dataset
#
# The data in this example is taken from the GEFCom2014 forecasting competition<sup>1</sup>. It consists of 3 years of hourly electricity load and temperature values between 2012 and 2014. The task is to forecast future values of electricity load.
#
# <sup>1</sup>Tao Hong, Pierre Pinson, Shu Fan, Hamidreza Zareipour, Alberto Troccoli and Rob J. Hyndman, "Probabilistic energy forecasting: Global Energy Forecasting Competition 2014 and beyond", International Journal of Forecasting, vol.32, no.3, pp 896-913, July-September, 2016.

# %%
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
from collections import UserDict
from IPython.display import Image
# %matplotlib inline

from common.utils import load_data, mape, TimeSeriesTensor, create_evaluation_df

pd.options.display.float_format = '{:,.20f}'.format
np.set_printoptions(precision=20)
warnings.filterwarnings("ignore")

# %%
var_name = 'Crc'
sat_var = 2

# %%
Paras = {
     'M0':['M0'],
    'e':['OMEGA','i0','omega','I_dot','Cus','Crs','e' , 'M0'],
    'sqrt_A':['Cuc','Crc','Del_n','Crs','sqrt_A','OMEGA_dot','Cus'],
    'OMEGA':['OMEGA','e','i0','omega'],
    'i0':['e','i0','omega','OMEGA' ,'I_dot'],
    'omega':['omega','e','OMEGA','i0'],
    'I_dot':['I_dot','e','Crs','Cuc'],
    'Cic':['M0','Cic'],
    'Cis':['Cis'],
    'OMEGA_dot':['OMEGA_dot','sqrt_A','Crc','Del_n','Cus' , 'omega' ],
    'Cuc':['Cuc','e','sqrt_A','I_dot','Crs'],
    'Cus':['Cus','sqrt_A','OMEGA_dot','Crc','Del_n','Cus'],
    'Crc':['Crc','sqrt_A','OMEGA_dot','Cus','Del_n'],
    'Crs':['Crs','e','sqrt_A','I_dot','Cuc'],
    'Del_n':['Crc','sqrt_A','OMEGA_dot','Cus','Del_n'],
    'Codes' : ['Codes']    
}

# %%
df = pd.read_csv("hourinterpol_21.csv" , parse_dates = True)
a = pd.to_datetime(df['Epoch_Time_of_Clock'])
print(type(a[0]))
#df = df.drop(['Unnamed: 0', 'Unnamed: 0.1' ,'sqrt_A'  ,'PRN','SV_Clock_Bias', 'SV_Clock_Drift', 'SV_Clock_Drift_Rate', 'IODE', 'Crs',
#       'Del_n', 'Cuc','Cus','Toe', 'Cic', 
#       'Cis', 'Crc', 'M0', 'OMEGA_dot', 'I_dot', 'Codes', 'GPS_week',
#       'L2_P_Data_flag', 'SV_accuracy', 'SV_health', 'Tgd', 'IODC', 'T_Tx',
#       'Fit_Interval' ,'Epoch_Time_of_Clock' ],axis =1 )
df = df.loc[:,Paras[var_name]]
#df.head()
#df = df.set_index(['Epoch_Time_of_Clock'])
df = df.set_index(a)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0d1a6d0d8c3d> in <module>()
# ----> 1 df = pd.read_csv("hourinterpol_21.csv" , parse_dates = True)
#       2 a = pd.to_datetime(df['Epoch_Time_of_Clock'])
#       3 print(type(a[0]))
#       4 #df = df.drop(['Unnamed: 0', 'Unnamed: 0.1' ,'sqrt_A'  ,'PRN','SV_Clock_Bias', 'SV_Clock_Drift', 'SV_Clock_Drift_Rate', 'IODE', 'Crs',
#       5 #       'Del_n', 'Cuc','Cus','Toe', 'Cic',
#
# NameError: name 'pd' is not defined

# %%
test = df.iloc[265:408,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3b5f5b158241> in <module>()
# ----> 1 test = df.iloc[265:408,:]
#
# NameError: name 'df' is not defined

# %%
df.head(7)
# Out:
#                                          Crc
# Epoch_Time_of_Clock
# 2017-11-02 22:00:00 289.59375000000000000000
# 2017-11-03 12:00:00 266.28125000000000000000
# 2017-11-03 14:00:00 255.40625000000000000000
# 2017-11-03 16:00:00 254.87500000000000000000
# 2017-11-03 18:00:00 257.34375000000000000000
# 2017-11-03 20:00:00 261.40625000000000000000
# 2017-11-03 22:00:00 257.84375000000000000000

# %% [markdown]
# # Enter number of entries per day

# %%
entry = 6
print(df.shape[0])
no_of_entries = df.shape[0]//entry
valid = (no_of_entries * 70)//100
test = (no_of_entries * 85)//100
indexes = df.index
#print(valid , test , indexes)
valid_start_dt = indexes[int(valid)*int(entry)] 
test_start_dt = indexes [int(test)*int(entry)] 
test_start_dt = str(test_start_dt)
valid_start_dt = str(valid_start_dt)
print(test_start_dt,valid_start_dt)
print(type(test_start_dt))
# Out:
# 163
# 2017-11-24 22:00:00 2017-11-20 22:00:00
# <class 'str'>

# %% [markdown]
# Load data into Pandas dataframe

# %% [markdown]
# # enter lag and no. of outputs

# %%
"""total = len(df)
t = total*70/100
t = round(t)
indexes = df.index
valid_start_dt = str(indexes[t])
t = total*85/100
t = round(t)
test_start_dt = str(indexes[t])
print(valid_start_dt , test_start_dt)
"""
T = 6
HORIZON = 6

# %% [markdown]
# Create training set containing only the model features

# %%
train = df.copy()[df.index < valid_start_dt][[var_name ]]
train.head()
# Out:
#                                          Crc
# Epoch_Time_of_Clock
# 2017-11-02 22:00:00 289.59375000000000000000
# 2017-11-03 12:00:00 266.28125000000000000000
# 2017-11-03 14:00:00 255.40625000000000000000
# 2017-11-03 16:00:00 254.87500000000000000000
# 2017-11-03 18:00:00 257.34375000000000000000

# %%
train.tail(6)
# Out:
#                                          Crc
# Epoch_Time_of_Clock
# 2017-11-19 22:00:00 181.78125000000000000000
# 2017-11-20 12:00:00 169.65625000000000000000
# 2017-11-20 14:00:00 168.31250000000000000000
# 2017-11-20 16:00:00 179.53125000000000000000
# 2017-11-20 18:00:00 187.56250000000000000000
# 2017-11-20 20:00:00 188.25000000000000000000

# %% [markdown]
# Scale data to be in range (0, 1). This transformation should be calibrated on the training set only. This is to prevent information from the validation or test sets leaking into the training data.

# %% [markdown]
# # Enter variable to be predicted

# %%
from sklearn.preprocessing import StandardScaler



y_scalar = StandardScaler()
y_scalar.fit(train[[var_name]])


X_scaler = StandardScaler()
train[[var_name]] = X_scaler.fit_transform(train)

# %% [markdown]
# Use the TimeSeriesTensor convenience class to:
# 1. Shift the values of the time series to create a Pandas dataframe containing all the data for a single training example
# 2. Discard any samples with missing values
# 3. Transform this Pandas dataframe into a numpy array of shape (samples, time steps, features) for input into Keras
#
# The class takes the following parameters:
#
# - **dataset**: original time series
# - **H**: the forecast horizon
# 2017-11-08 14:00:00 -1.16348311509497270855 -0.92860151749077124439
# 2017-11-08 16:00:00 -0.92860151749077124439 -0.79506824771578787914
# 2017-11-08 18:00:00 -0.79506824771578787914 -0.94846031145730724798
# ...                                     ...                     ...
# 2017-11-14 22:00:00  1.26476803681318639150  1.26339846481549411550
# 2017-11-15 12:00:00  1.26339846481549411550  1.04974523317552081991
# 2017-11-15 14:00:00  1.04974523317552081991  1.06549531114898043960
# 2017-11-15 16:00:00  1.06549531114898043960  0.95866869532899368078
# 2017-11-15 18:00:00  0.95866869532899368078  0.91621196340053745466
# 2017-11-15 20:00:00  0.91621196340053745466  0.82239628155862598557
# 2017-11-15 22:00:00  0.82239628155862598557  0.80801577558285864189
# 2017-11-16 12:00:00  0.80801577558285864189  0.52588394405827831868
# 2017-11-16 14:00:00  0.52588394405827831868  0.55464495600981322809
# 2017-11-16 16:00:00  0.55464495600981322809  0.46767713415636252838
# 2017-11-16 18:00:00  0.46767713415636252838  0.42316604423136805480
# 2017-11-16 20:00:00  0.42316604423136805480  0.30880678242407461065
# 2017-11-16 22:00:00  0.30880678242407461065  0.24854561452562060064
# 2017-11-17 12:00:00  0.24854561452562060064 -0.07672773492626197567
# 2017-11-17 14:00:00 -0.07672773492626197567 -0.03701014699318999623
# 2017-11-17 16:00:00 -0.03701014699318999623 -0.05755372695857205456
# 2017-11-17 18:00:00 -0.05755372695857205456 -0.06782551694126308373
# 2017-11-17 20:00:00 -0.06782551694126308373 -0.17944563475317226731
# 2017-11-17 22:00:00 -0.17944563475317226731 -0.30407668654315672674
# 2017-11-18 12:00:00 -0.30407668654315672674 -0.64441532796965284025
# 2017-11-18 14:00:00 -0.64441532796965284025 -0.60812167003081118999
# 2017-11-18 16:00:00 -0.60812167003081118999 -0.53347999615658969752
# 2017-11-18 18:00:00 -0.53347999615658969752 -0.48349061824082667504
# 2017-11-18 20:00:00 -0.48349061824082667504 -0.56977365409543134778
# 2017-11-18 22:00:00 -0.56977365409543134778 -0.75466587378386984497
# 2017-11-19 12:00:00 -0.75466587378386984497 -1.07651529324152206435
# 2017-11-19 14:00:00 -1.07651529324152206435 -1.06350435926344677462
# 2017-11-19 16:00:00 -1.06350435926344677462 -0.89093828755423742916
# 2017-11-19 18:00:00 -0.89093828755423742916 -0.77315509575271368359
# 2017-11-19 20:00:00 -0.77315509575271368359 -0.81355746968463171775
#
# [97 rows x 12 columns]

# %%
train_inputs['target'].shape
# Out:
# (97, 6)

# %% [markdown]
# Construct validation set (keeping T hours from the training set in order to construct initial features)

# %%
look_back_dt = dt.datetime.strptime(valid_start_dt, '%Y-%m-%d %H:%M:%S') - dt.timedelta(hours=T-1)
valid = df.copy()[(df.index >=look_back_dt) & (df.index < test_start_dt)][[var_name]]
valid[[var_name]] = X_scaler.transform(valid)
valid_inputs = TimeSeriesTensor(valid, var_name, HORIZON, tensor_structure,freq = None)
valid_inputs.dataframe.head()
# Out:
# tensor                               target                          \
# feature                                   y
# time step                               t+1                     t+2
# Epoch_Time_of_Clock
# 2017-11-21 16:00:00 -0.87929692557385430440 -0.80670960969617100389
# 2017-11-21 18:00:00 -0.80670960969617100389 -0.97859089540653421135
# 2017-11-21 19:59:44 -0.97859089540653421135 -1.03953684930383438711
# 2017-11-21 22:00:00 -1.03953684930383438711 -1.16827661708689523046
# 2017-11-22 12:00:00 -1.16827661708689523046 -0.91764494150923414661
#
# tensor                                                               \
# feature
# time step                               t+3                     t+4
# Epoch_Time_of_Clock
# 2017-11-21 16:00:00 -0.97859089540653421135 -1.03953684930383438711
# 2017-11-21 18:00:00 -1.03953684930383438711 -1.16827661708689523046
# 2017-11-21 19:59:44 -1.16827661708689523046 -0.91764494150923414661
# 2017-11-21 22:00:00 -0.91764494150923414661 -0.70056777987503038307
# 2017-11-22 12:00:00 -0.70056777987503038307 -0.57867587208043025360
#
# tensor                                                               \
# feature
# time step                               t+5                     t+6
# Epoch_Time_of_Clock
# 2017-11-21 16:00:00 -1.16827661708689523046 -0.91764494150923414661
# 2017-11-21 18:00:00 -0.91764494150923414661 -0.70056777987503038307
# 2017-11-21 19:59:44 -0.70056777987503038307 -0.57867587208043025360
# 2017-11-21 22:00:00 -0.57867587208043025360 -0.66975240992695728171
# 2017-11-22 12:00:00 -0.66975240992695728171 -0.61154560002504154692
#
# tensor                                    X                          \
# feature                                 Crc
# time step                               t-5                     t-4
# Epoch_Time_of_Clock
# 2017-11-21 16:00:00 -0.90737315152654307582 -0.89230785955192959413
# 2017-11-21 18:00:00 -0.89230785955192959413 -1.10938502118613335767
# 2017-11-21 19:59:44 -1.10938502118613335767 -1.28400545089188078407
# 2017-11-21 22:00:00 -1.28400545089188078407 -1.36481019875571685240
# 2017-11-22 12:00:00 -1.36481019875571685240 -1.09089579921728940803
#
# tensor                                                               \
# feature
# time step                               t-3                     t-2
# Epoch_Time_of_Clock
# 2017-11-21 16:00:00 -1.10938502118613335767 -1.28400545089188078407
# 2017-11-21 18:00:00 -1.28400545089188078407 -1.36481019875571685240
# 2017-11-21 19:59:44 -1.36481019875571685240 -1.09089579921728940803
# 2017-11-21 22:00:00 -1.09089579921728940803 -0.87929692557385430440
# 2017-11-22 12:00:00 -0.87929692557385430440 -0.80670960969617100389
#
# tensor
# feature
# time step                               t-1                       t
# Epoch_Time_of_Clock
# 2017-11-21 16:00:00 -1.36481019875571685240 -1.09089579921728940803
# 2017-11-21 18:00:00 -1.09089579921728940803 -0.87929692557385430440
# 2017-11-21 19:59:44 -0.87929692557385430440 -0.80670960969617100389
# 2017-11-21 22:00:00 -0.80670960969617100389 -0.97859089540653421135
# 2017-11-22 12:00:00 -0.97859089540653421135 -1.03953684930383438711

# %% [markdown]
# ## Implement the RNN

# %% [markdown]
# We will implement a RNN forecasting model with the following structure:

# %%
#Image('./images/simple_encoder_decoder.png')

# %%
from keras.models import Model, Sequential
from keras.layers import LSTM, Dense, RepeatVector, TimeDistributed, Flatten
from keras.callbacks import EarlyStopping ,ModelCheckpoint

# %%
LATENT_DIM = 64
BATCH_SIZE = 8
EPOCHS = 10

# %%
model = Sequential()
model.add(LSTM(LATENT_DIM, input_shape=(T,1 )))
model.add(RepeatVector(HORIZON))
model.add(LSTM(LATENT_DIM, return_sequences=True))
model.add(TimeDistributed(Dense(1)))
model.add(Flatten())

# %%
model.compile(optimizer='RMSprop', loss='mse')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 64)                16896
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 6, 64)             0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 6, 64)             33024
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 6, 1)              65
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6)                 0
# =================================================================
# Total params: 49,985
# Trainable params: 49,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=500)

# %%
best_val = ModelCheckpoint(str(sat_var) +'_' +  var_name + '_{epoch:02d}.h5', save_best_only=True, mode='min', period=1)

# %%
history = model.fit(train_inputs['X'],
          train_inputs['target'],
          batch_size=BATCH_SIZE,
          epochs=EPOCHS,
          validation_data=(valid_inputs['X'], valid_inputs['target']),
          callbacks=[earlystop ,best_val],
          verbose=1 , shuffle = False)
# Out:
# Train on 97 samples, validate on 15 samples
# Epoch 1/10
# 97/97 [==============================] - 1s 15ms/step - loss: 0.7817 - val_loss: 0.1487
# Epoch 2/10
# 97/97 [==============================] - 0s 1ms/step - loss: 0.4406 - val_loss: 0.1974
# Epoch 3/10
# 97/97 [==============================] - 0s 2ms/step - loss: 0.3965 - val_loss: 0.1884
# Epoch 4/10
# 97/97 [==============================] - 0s 3ms/step - loss: 0.3737 - val_loss: 0.1802
# Epoch 5/10
# 97/97 [==============================] - 0s 4ms/step - loss: 0.3544 - val_loss: 0.1728
# Epoch 6/10
# 97/97 [==============================] - 0s 2ms/step - loss: 0.3368 - val_loss: 0.1659
# Epoch 7/10
# 97/97 [==============================] - 0s 2ms/step - loss: 0.3207 - val_loss: 0.1595
# Epoch 8/10
# 97/97 [==============================] - 0s 2ms/step - loss: 0.3058 - val_loss: 0.1538
# Epoch 9/10
# 97/97 [==============================] - 0s 2ms/step - loss: 0.2921 - val_loss: 0.1490
# Epoch 10/10
# 97/97 [==============================] - 0s 2ms/step - loss: 0.2796 - val_loss: 0.1450

# %%
best_epoch = np.argmin(np.array(history.history['val_loss']))+1
model.load_weights(str(sat_var) +'_' +  var_name + '_{:02d}.h5'.format(best_epoch))

# %% [markdown]
# ## Evaluate the model

# %%
look_back_dt = dt.datetime.strptime(test_start_dt, '%Y-%m-%d %H:%M:%S') - dt.timedelta(hours=T-1)
test = df.copy()[test_start_dt:][[var_name]]
test[[var_name]] = X_scaler.transform(test)
test_inputs = TimeSeriesTensor(test, var_name, HORIZON, tensor_structure,freq =None)
test_inputs.dataframe.head()
# Out:
# tensor                              target                         \
# feature                                  y
# time step                              t+1                    t+2
# Epoch_Time_of_Clock
# 2017-11-25 20:00:00 0.77446126163940121057 0.96757091331399258660
# 2017-11-25 22:00:00 0.96757091331399258660 0.86485301348708232272
# 2017-11-26 12:00:00 0.86485301348708232272 0.78747219561747650030
# 2017-11-26 14:00:00 0.78747219561747650030 0.84362464752285415415
# 2017-11-26 16:00:00 0.84362464752285415415 0.96757091331399258660
#
# tensor                                                             \
# feature
# time step                              t+3                    t+4
# Epoch_Time_of_Clock
# 2017-11-25 20:00:00 0.86485301348708232272 0.78747219561747650030
# 2017-11-25 22:00:00 0.78747219561747650030 0.84362464752285415415
# 2017-11-26 12:00:00 0.84362464752285415415 0.96757091331399258660
# 2017-11-26 14:00:00 0.96757091331399258660 1.17643064296204347130
# 2017-11-26 16:00:00 1.17643064296204347130 1.26682239480972458345
#
# tensor                                                             \
# feature
# time step                              t+5                    t+6
# Epoch_Time_of_Clock
# 2017-11-25 20:00:00 0.84362464752285415415 0.96757091331399258660
# 2017-11-25 22:00:00 0.96757091331399258660 1.17643064296204347130
# 2017-11-26 12:00:00 1.17643064296204347130 1.26682239480972458345
# 2017-11-26 14:00:00 1.26682239480972458345 1.21546344489626934049
# 2017-11-26 16:00:00 1.21546344489626934049 1.12164776305435798243
#
# tensor                                   X                         \
# feature                                Crc
# time step                              t-5                    t-4
# Epoch_Time_of_Clock
# 2017-11-25 20:00:00 0
#         0.897849  ],
#        [0.58395034, 0.8922777 , 1.0107797 , 1.0173502 , 0.9661094 ,
#         0.89141244],
#        [0.59700173, 0.911037  , 1.0307628 , 1.0363678 , 0.9833333 ,
#         0.90670896],
#        [0.62887454, 0.9634428 , 1.0953109 , 1.1075252 , 1.0575551 ,
#         0.98176193],
#        [0.63896704, 0.97978574, 1.1151417 , 1.1290954 , 1.0797982 ,
#         1.0040419 ],
#        [0.64603645, 0.9900849 , 1.126296  , 1.1399217 , 1.0898182 ,
#         1.0131409 ],
#        [0.6432435 , 0.98288   , 1.1144067 , 1.1239197 , 1.0706236 ,
#         0.99170506],
#        [0.6444583 , 0.98328614, 1.1130853 , 1.1207321 , 1.0658199 ,
#         0.98566437],
#        [0.64520746, 0.9840529 , 1.1135013 , 1.1206946 , 1.0653615 ,
#         0.98487   ],
#        [0.6531419 , 0.99882054, 1.1336768 , 1.1448439 , 1.0921993 ,
#         1.013339  ]], dtype=float32)

# %%
eval_df = create_evaluation_df(predictions, test_inputs, HORIZON, y_scalar)
print(eval_df.head())
print(eval_df.tail())
print(eval_df.shape)
# Out:
#             timestamp    h               prediction                   actual
# 0 2017-11-25 20:00:00  t+1 236.31770010172087381761 264.31250000000000000000
# 1 2017-11-25 22:00:00  t+1 239.22248361043173758844 273.12500000000000000000
# 2 2017-11-26 12:00:00  t+1 242.83612444282601927625 268.43750000000000000000
# 3 2017-11-26 14:00:00  t+1 245.08289361119142313328 264.90625000000000000000
# 4 2017-11-26 16:00:00  t+1 246.08195469773139052450 267.46875000000000000000
#               timestamp    h               prediction                   actual
# 115 2017-11-28 14:00:00  t+6 275.20457319819342956180 275.34375000000000000000
# 116 2017-11-28 16:00:00  t+6 274.22635441637351050304 275.75000000000000000000
# 117 2017-11-28 18:00:00  t+6 273.95068926607535786388 279.06250000000000000000
# 118 2017-11-28 20:00:00  t+6 273.91443929609113183687 277.43750000000000000000
# 119 2017-11-28 22:00:00  t+6 275.21361461038128481960 274.03125000000000000000
# (120, 4)

# %%
eval_df['APE'] = (eval_df['prediction'] - eval_df['actual']).abs() / eval_df['actual']
eval_df.groupby('h')['APE'].mean()
# Out:
# h
# t+1   0.10103061276868260943
# t+2   0.05931420755524127036
# t+3   0.04761986068981483716
# t+4   0.04876909386848951589
# t+5   0.05490874582131247822
# t+6   0.06298976866870890923
# Name: APE, dtype: float64

# %%
mape(eval_df['prediction'], eval_df['actual'])
from sklearn.metrics import mean_absolute_error
a = mean_absolute_error(eval_df['prediction'], eval_df['actual'])
a
# Out:
# 17.58941494114337

# %% [markdown]
# Plot actuals vs predictions at each horizon for first week of the test period. As is to be expected, predictions for one step ahead (*t+1*) are more accurate than those for 2 or 3 steps ahead

# %%
plot_df = eval_df[(eval_df.h=='t+1')][['timestamp', 'actual']]
for t in range(1, HORIZON+1):
    plot_df['t+'+str(t)] = eval_df[ (eval_df.h=='t+'+str(t))]['prediction'].values

fig = plt.figure(figsize=(15, 8))
ax = plt.plot(plot_df['timestamp'], plot_df['actual'], color='red', linewidth=4.0)
ax = fig.add_subplot(111)
ax.plot(plot_df['timestamp'], plot_df['t+1'], color='blue', linewidth=4.0, alpha=0.75)
ax.plot(plot_df['timestamp'], plot_df['t+2'], color='blue', linewidth=3.0, alpha=0.5)
ax.plot(plot_df['timestamp'], plot_df['t+3'], color='blue', linewidth=2.0, alpha=0.25)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
ax.legend(loc='best')
plt.show()

# %% [markdown]
# # take input here

# %%
a = df.iloc[156:162  , :]
a
# Out:
#                                          Crc
# Epoch_Time_of_Clock
# 2017-11-27 14:00:00 284.43750000000000000000
# 2017-11-27 16:00:00 280.15625000000000000000
# 2017-11-27 18:00:00 281.68750000000000000000
# 2017-11-27 20:00:00 284.90625000000000000000
# 2017-11-27 22:00:00 292.59375000000000000000
# 2017-11-28 12:00:00 288.25000000000000000000

# %%
new_df = pd.DataFrame()

# %%
columns = [var_name]

# %%
for key , value in enumerate(columns):
    new_df[value] = a[value]

# %%
new_df = new_df.dropna( how = 'any')

# %%
new_df
# Out:
#                                          Crc
# Epoch_Time_of_Clock
# 2017-11-27 14:00:00 284.43750000000000000000
# 2017-11-27 16:00:00 280.15625000000000000000
# 2017-11-27 18:00:00 281.68750000000000000000
# 2017-11-27 20:00:00 284.90625000000000000000
# 2017-11-27 22:00:00 292.59375000000000000000
# 2017-11-28 12:00:00 288.25000000000000000000

# %%
# creating index for output
import datetime
date = new_df.index.date[0]
date + datetime.timedelta(1)
# Out:
# datetime.date(2017, 11, 28)

# %%
import datetime
date = new_df.index + datetime.timedelta(days =1)

# %%
date
# Out:
# DatetimeIndex(['2017-11-28 14:00:00', '2017-11-28 16:00:00',
#                '2017-11-28 18:00:00', '2017-11-28 20:00:00',
#                '2017-11-28 22:00:00', '2017-11-29 12:00:00'],
#               dtype='datetime64[ns]', name='Epoch_Time_of_Clock', freq=None)

# %%
new_df.index= date

# %%
new_df.columns
# Out:
# Index(['Crc'], dtype='object')

# %%
print(new_df)
print(new_df.columns)
# Out:
#                                          Crc
# Epoch_Time_of_Clock
# 2017-11-28 14:00:00 284.43750000000000000000
# 2017-11-28 16:00:00 280.15625000000000000000
# 2017-11-28 18:00:00 281.68750000000000000000
# 2017-11-28 20:00:00 284.90625000000000000000
# 2017-11-28 22:00:00 292.59375000000000000000
# 2017-11-29 12:00:00 288.25000000000000000000
# Index(['Crc'], dtype='object')

# %%
freq = None
idx_tuples = []
drop_incomplete  = True
new_df[[var_name]] = X_scaler.transform(new_df)
new_new_df = new_df.copy()
tensor_structure={'X':(range(-T+1, 1), [var_name])}
for name, structure in tensor_structure.items():
        rng = structure[0]
        dataset_cols = structure[1]
        for col in dataset_cols:
        # do not shift non-sequential 'static' features
            if rng is None:
                new_df['context_'+col] = new_df[col]
                idx_tuples.append((name, col, 'static'))
            else:
                for t in rng:
                    sign = '+' if t > 0 else ''
                    shift = str(t) if t != 0 else ''
                    period = 't'+sign+shift
                    shifted_col = name+'_'+col+'_'+ period
                    new_new_df[shifted_col] = new_new_df[col].shift(t*-1, freq=freq)
                    idx_tuples.append((name, col, period))
        new_new_df = new_new_df.drop(new_df.columns, axis=1)
        idx = pd.MultiIndex.from_tuples(idx_tuples, names=['tensor', 'feature', 'time step'])
        print(new_df.head())
        new_new_df.columns = idx
        if drop_incomplete:
            new_new_df = new_new_df.dropna(how='any')
            
inputs = {}           
for name, structure in tensor_structure.items():
    rng = structure[0]
    cols = structure[1]
    tensor = new_new_df[name][cols].as_matrix()
    if rng is None:
        tensor = tensor.reshape(tensor.shape[0], len(cols))
    else:
        tensor = tensor.reshape(tensor.shape[0], len(cols), len(rng))
        tensor = np.transpose(tensor, axes=[0, 2, 1])
    inputs[name] = tensor
# Out:
#                                        Crc
# Epoch_Time_of_Clock
# 2017-11-28 14:00:00 1.21546344489626934049
# 2017-11-28 16:00:00 1.12164776305435798243
# 2017-11-28 18:00:00 1.15520227699781541375
# 2017-11-28 20:00:00 1.22573523487896030026
# 2017-11-28 22:00:00 1.39419259059509337284

# %%
print(new_new_df)
print(inputs['X'])
# Out:
# tensor                                   X                         \
# feature                                Crc
# time step                              t-5                    t-4
# Epoch_Time_of_Clock
# 2017-11-29 12:00:00 1.21546344489626934049 1.12164776305435798243
#
# tensor                                                             \
# feature
# time step                              t-3                    t-2
# Epoch_Time_of_Clock
# 2017-11-29 12:00:00 1.15520227699781541375 1.22573523487896030026
#
# tensor
# feature
# time step                              t-1                      t
# Epoch_Time_of_Clock
# 2017-11-29 12:00:00 1.39419259059509337284 1.29900733675548973878
# [[[1.2154634448962693]
#   [1.121647763054358 ]
#   [1.1552022769978154]
#   [1.2257352348789603]
#   [1.3941925905950934]
#   [1.2990073367554897]]]

# %%
predictions = model.predict(inputs['X'])

# %%
predictions
# Out:
# array([[0.63896704, 0.97978574, 1.1151417 , 1.1290954 , 1.0797982 ,
#         1.0040419 ]], dtype=float32)

# %%
print(predictions.shape)
# Out:
# (1, 6)

# %%
results = predictions[-1, :]

# %%
results
# Out:
# array([0.63896704, 0.97978574, 1.1151417 , 1.1290954 , 1.0797982 ,
#        1.0040419 ], dtype=float32)

# %%
res_df = pd.DataFrame(results , columns = [var_name])
res_df
# Out:
#                      Crc
# 0 0.63896703720092773438
# 1 0.97978574037551879883
# 2 1.11514174938201904297
# 3 1.12909543514251708984
# 4 1.07979822158813476562
# 5 1.00404191017150878906

# %%
res_df.index = date
res_df
# Out:
#                                        Crc
# Epoch_Time_of_Clock
# 2017-11-28 14:00:00 0.63896703720092773438
# 2017-11-28 16:00:00 0.97978574037551879883
# 2017-11-28 18:00:00 1.11514174938201904297
# 2017-11-28 20:00:00 1.12909543514251708984
# 2017-11-28 22:00:00 1.07979822158813476562
# 2017-11-29 12:00:00 1.00404191017150878906

# %%
res_df[var_name] = y_scalar.inverse_transform(res_df[[var_name]])

# %% [markdown]
# # final generated output

# %%
# final generated ouput
res_df
# Out:
#                                          Crc
# Epoch_Time_of_Clock
# 2017-11-28 14:00:00 258.12927246093750000000
# 2017-11-28 16:00:00 273.68243408203125000000
# 2017-11-28 18:00:00 279.85934448242187500000
# 2017-11-28 20:00:00 280.49612426757812500000
# 2017-11-28 22:00:00 278.24645996093750000000
# 2017-11-29 12:00:00 274.78933715820312500000

# %%
res_df.to_csv('SA1_Crc.csv')
